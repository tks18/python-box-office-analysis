# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
3.29e7
# Out:
# 32900000.0

# %%
X = DataFrame(data, columns=['production_budget_usd'])
y = DataFrame(data, columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, y, alpha=0.3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %%
regression = LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope coefficient:

# %%
regression.coef_    # theta_1
# Out:
# array([[3.11150918]])

# %%
#Intercept
regression.intercept_
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, y, alpha=0.3)

# Adding the regression line here:
plt.plot(X, regression.predict(X), color='red', linewidth=3)

plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %%
#Getting r square from Regression
regression.score(X, y)
# Out:
# 0.5496485356985729

# %% [markdown]
# ### Results
#
# ### Simply we have to substitute the Production Budget in our Model
#
# ### (i.e) Revenue from Movie = regression Intercept from Above + (coefficient * Production Budget)
# ### in our Model = $R(x) = -7236192.73 + (3.115 * x)$ where x is the Production Budget
